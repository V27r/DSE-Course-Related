# %% [markdown]
# # Week 7
# # 29 March, 2023

# %% [markdown]
# ### Write the python code to build the following models: (1).Naive Bayes (2).SVM Build the models for atleast 4 datasets, with at least 4 train_test_split combinations. Perform the data pre-processing and performance evaluation for the models.

# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix

from sklearn.datasets import make_classification

n_samples = 1000
n_features = 20
n_classes = 2

X1, y1 = make_classification(n_samples=n_samples, n_features=n_features, n_classes=n_classes)
X2, y2 = make_classification(n_samples=n_samples, n_features=n_features, n_classes=n_classes)
X3, y3 = make_classification(n_samples=n_samples, n_features=n_features, n_classes=n_classes)
X4, y4 = make_classification(n_samples=n_samples, n_features=n_features, n_classes=n_classes)

datasets = [(X1, y1), (X2, y2), (X3, y3), (X4, y4)]
split_ratios = [0.2, 0.3, 0.4, 0.5]

for data in datasets:
    X, y = data
    for split_ratio in split_ratios:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split_ratio)
        # Naive Bayes
        nb = GaussianNB()
        nb.fit(X_train, y_train)
        nb_pred = nb.predict(X_test)
        nb_acc = confusion_matrix(y_test, nb_pred)
            
        # SVM
        svm = SVC()
        svm.fit(X_train, y_train)
        svm_pred = svm.predict(X_test)
        svm_acc = confusion_matrix(y_test, svm_pred)
            
        print(f"Split ratio: {split_ratio}")
        print(f"Naive Bayes accuracy: {nb_acc}")
        print(f"SVM accuracy: {svm_acc}")
        print("\n")
# Out:
# Split ratio: 0.2
# Naive Bayes accuracy: [[77 28]
#  [ 9 86]]
# SVM accuracy: [[79 26]
#  [ 8 87]]
#
#
# Split ratio: 0.3
# Naive Bayes accuracy: [[115  39]
#  [ 20 126]]
# SVM accuracy: [[118  36]
#  [ 19 127]]
#
#
# Split ratio: 0.4
# Naive Bayes accuracy: [[153  48]
#  [ 28 171]]
# SVM accuracy: [[152  49]
#  [ 23 176]]
#
#
# Split ratio: 0.5
# Naive Bayes accuracy: [[172  58]
#  [ 52 218]]
# SVM accuracy: [[175  55]
#  [ 48 222]]
#
#
# Split ratio: 0.2
# Naive Bayes accuracy: [[86 14]
#  [12 88]]
# SVM accuracy: [[84 16]
#  [10 90]]
#
#
# Split ratio: 0.3
# Naive Bayes accuracy: [[122  25]
#  [ 23 130]]
# SVM accuracy: [[125  22]
#  [ 17 136]]
#
#
# Split ratio: 0.4
# Naive Bayes accuracy: [[174  20]
#  [ 21 185]]
# SVM accuracy: [[175  19]
#  [ 20 186]]
#
#
# Split ratio: 0.5
# Naive Bayes accuracy: [[230  28]
#  [ 43 199]]
# SVM accuracy: [[229  29]
#  [ 27 215]]
#
#
# Split ratio: 0.2
# Naive Bayes accuracy: [[93  3]
#  [ 7 97]]
# SVM accuracy: [[ 94   2]
#  [  4 100]]
#
#
# ...
